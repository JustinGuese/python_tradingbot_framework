# %%
import pandas as pd

df = pd.read_csv('data/FXStabilizer_EUR - Turbo.csv')
df
# Out:
#              Open Date        Close Date  Symbol   Action  Units/Lots  \
# 0     08/01/2025 15:35  08/01/2025 17:28  EURUSD     Sell        0.02
# 1     08/01/2025 14:53  08/01/2025 17:28  EURUSD     Sell        0.01
# 2     08/01/2025 14:45  08/01/2025 17:28  EURUSD     Sell        0.01
# 3     07/30/2025 21:03  08/01/2025 14:31  EURUSD      Buy        0.08
# 4     07/30/2025 20:45  08/01/2025 14:31  EURUSD      Buy        0.04
# ...                ...               ...     ...      ...         ...
# 4947  04/05/2016 17:35  04/06/2016 10:17  EURUSD     Sell        0.01
# 4948  04/05/2016 09:15  04/05/2016 17:34  EURUSD      Buy        0.04
# 4949  04/04/2016 08:56  04/05/2016 17:34  EURUSD      Buy        0.02
# 4950  04/04/2016 05:00  04/05/2016 17:34  EURUSD      Buy        0.01
# 4951  04/04/2016 04:10               NaN     NaN  Deposit        0.00
#
#       Open Price  Close Price  Commission  Swap  Pips  ...  Drawdown  \
# 0        1.15808      1.15377        -0.2  0.00  43.1  ...      32.9
# 1        1.15557      1.15377        -0.1  0.00  18.0  ...      44.1
# 2        1.15300      1.15377        -0.1  0.00  -7.7  ...      54.4
# 3        1.14223      1.14667        -0.8 -3.89  44.4  ...      64.7
# 4        1.14565      1.14667        -0.4 -1.95  10.2  ...      64.7
# ...          ...          ...         ...   ...   ...  ...       ...
# 4947     1.13890      1.13440         0.0  0.01  45.0  ...       7.4
# 4948     1.13480      1.13930         0.0  0.00  45.0  ...      16.3
# 4949     1.13730      1.13930         0.0 -0.10  20.0  ...      50.3
# 4950     1.13980      1.13930         0.0 -0.05  -5.0  ...      46.3
# 4951     0.00000      0.00000         0.0  0.00   0.0  ...       NaN
#
#       Risk:Reward Max(pips)  Max(USD) Min(pips)  Min(USD)  Entry Accuracy(%)  \
# 0            0.08      43.3      8.66      -3.6     -0.72               92.3
# 1            1.58      18.2      1.82     -28.7     -2.87               38.8
# 2           54.64       0.0      0.00     -54.4     -5.44                0.0
# 3            0.48      59.6     47.68     -28.6    -22.88               67.6
# 4            2.47      25.4     10.16     -62.8    -25.12               28.8
# ...           ...       ...       ...       ...       ...                ...
# 4947         0.15      45.0      4.50      -6.8     -0.68               86.9
# 4948         0.02      45.0     18.00       0.0      0.00              100.0
# 4949         0.58      31.9      6.38     -18.4     -3.68               63.4
# 4950        12.63       3.4      0.34     -42.9     -4.29                7.3
# 4951          NaN       NaN       NaN       NaN       NaN                NaN
#
#       Exit Accuracy(%)  ProfitMissed(pips)  ProfitMissed(USD)
# 0                 99.6                -0.2              -0.04
# 1                 99.6                -0.2              -0.02
# 2                 85.8                -7.7              -0.77
# 3                 82.8               -15.2             -12.16
# 4                 82.8               -15.2              -6.08
# ...                ...                 ...                ...
# 4947             100.0                 0.0               0.00
# 4948             100.0                 0.0               0.00
# 4949              76.3               -11.9              -2.38
# 4950              81.9                -8.4              -0.84
# 4951               NaN                 NaN                NaN
#
# [4952 rows x 25 columns]

# %%
df["Open Date"].min()
# Out:
# '01/06/2023 21:30'

# %%
df.columns
# Out:
# Index(['Open Date', 'Close Date', 'Symbol', 'Action', 'Units/Lots',
#        'Open Price', 'Close Price', 'Commission', 'Swap', 'Pips', 'Profit',
#        'Gain', 'Duration (DD:HH:MM:SS)', 'Profitable(%)',
#        'Profitable(time duration)', 'Drawdown', 'Risk:Reward', 'Max(pips)',
#        'Max(USD)', 'Min(pips)', 'Min(USD)', 'Entry Accuracy(%)',
#        'Exit Accuracy(%)', 'ProfitMissed(pips)', 'ProfitMissed(USD)'],
#       dtype='object')

# %%
import datetime

buy_trades = df[df['Action'] == 'Buy']
durations = buy_trades['Duration (DD:HH:MM:SS)'].dropna()

def duration_to_seconds(duration_str):
    dd, hh, mm, ss = map(int, duration_str.split(':'))
    return dd*86400 + hh*3600 + mm*60 + ss

seconds = durations.apply(duration_to_seconds)
median_seconds = seconds.median()

median_duration = str(datetime.timedelta(seconds=int(median_seconds)))
print("Median trade duration for Buy trades:", median_duration)
# Out:
# Median trade duration for Buy trades: 21:26:06

# %%
import yfinance as yf
from ta import add_all_ta_features
import matplotlib.pyplot as plt

data = yf.download('EURUSD=X',interval="5m", period="max")
# swap multilevel index
data = data.swaplevel(axis=1)
data = data["EURUSD=X"]
data = add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume")
data = data.ffill().bfill().fillna(0)
data['Close'].plot(figsize=(14, 7))
# Out:
# /var/folders/wq/5r6js2g51j3_3fb1s5zd343w0000gn/T/ipykernel_33781/967072691.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download('EURUSD=X',interval="5m", period="max")
# [*********************100%***********************]  1 of 1 completed
# /Users/jguese/code/myfxbookcopying/.venv/lib/python3.12/site-packages/ta/trend.py:1030: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self._psar[i] = high2
# <Axes: xlabel='Datetime'>

# %%
import numpy as np

# Initialize signal column with zeros
data['signal'] = 0

def nearest_slot(ts, slots):
    # Find the slot in slots that is closest to ts
    return slots[np.argmin(np.abs(slots - ts))]

for idx, row in df.iterrows():
    if row['Action'] in ['Buy', 'Sell'] and pd.notnull(row['Open Date']) and pd.notnull(row['Close Date']):
        open_dt = pd.to_datetime(row['Open Date'], utc=True)
        close_dt = pd.to_datetime(row['Close Date'], utc=True)
        # Find nearest slot in data.index
        open_slot = nearest_slot(open_dt, data.index)
        close_slot = nearest_slot(close_dt, data.index)
        if row['Action'] == 'Buy':
            data.at[open_slot, 'signal'] = 1
            data.at[close_slot, 'signal'] = -1
        elif row['Action'] == 'Sell':
            data.at[open_slot, 'signal'] = -1
            data.at[close_slot, 'signal'] = 1

data["signal"].value_counts()
# Out:
# signal
#  0    11933
# -1       74
#  1       65
# Name: count, dtype: int64

# %% [markdown]
# ## now that we have signal try to correlate

# %%
data["signal"].plot(figsize=(14, 7), title="Trading Signals")
# Out:
# <Axes: title={'center': 'Trading Signals'}, xlabel='Datetime'>

# %% [markdown]
# ## adapt signal
#
# i want to have it at either -1 or 1 depending on the last value until the other appears

# %%
# Adapt signal: fill forward with last non-zero value, then map to -1 or 1
def adapt_signal(series):
    # Replace zeros with NaN, then forward fill
    s = series.replace(0, np.nan).ffill()
    # If still NaN (at start), fill with first non-zero value
    first_nonzero = s.dropna().iloc[0] if not s.dropna().empty else 1
    s = s.fillna(first_nonzero)
    # Map all non-negative to 1, negative to -1
    return np.where(s < 0, -1, 1)

data["adapted_signal"] = adapt_signal(data["signal"])
data["adapted_signal"].plot(figsize=(14, 7), title="Adapted Trading Signal")
# Out:
# <Axes: title={'center': 'Adapted Trading Signal'}, xlabel='Datetime'>

# %% [markdown]
# ## clean signal
#
# if a lot of changes between 1 and -1 are close to another, ignore them to "smoothen" the signal

# %%
def smooth_signal(signal, min_interval=5):
    smoothed = signal.copy()
    current_value = smoothed.iloc[0]
    pending_value = current_value
    count = 0
    for i in range(1, len(smoothed)):
        if smoothed.iloc[i] != current_value:
            if smoothed.iloc[i] == pending_value:
                count += 1
            else:
                pending_value = smoothed.iloc[i]
                count = 1
            if count >= min_interval:
                current_value = pending_value
                count = 0
        else:
            count = 0
            pending_value = current_value
        smoothed.iloc[i] = current_value
    return smoothed

data["signal"] = smooth_signal(data["adapted_signal"], min_interval=100)
data["signal"].plot(figsize=(14, 7), title="Cleaned Trading Signal")
# Out:
# <Axes: title={'center': 'Cleaned Trading Signal'}, xlabel='Datetime'>

# %% [markdown]
# ### finetune signal smoothing

# %%
def tradeMetric(trades):
    return np.median(trades) * len(trades) / 100

# %%
def oneRun(signalthreshold = 100, startMoney = 10000, signalcolumnname="signal"):
    money = startMoney
    nrStocks = 0
    portfolio = []
    buyHold = []
    boughtAt = 0
    trades = []

    data[signalcolumnname] = smooth_signal(data["adapted_signal"], min_interval=signalthreshold)

    for i in range(len(data)):
        if data[signalcolumnname].iloc[i] == 1 and money > 0:
            # Buy signal
            nrStocks += money / data["Close"].iloc[i]
            money = 0
            boughtAt = data["Close"].iloc[i]
        elif data[signalcolumnname].iloc[i] == -1 and nrStocks > 0:
            # Sell signal
            money += nrStocks * data["Close"].iloc[i]
            nrStocks = 0
            win = data["Close"].iloc[i] - boughtAt
            trades.append(win)
        portfolio.append(money + nrStocks * data["Close"].iloc[i])
        buyHold.append(data["Close"].iloc[i] * startMoney / data["Close"].iloc[0])
    myTradeMetric = tradeMetric(trades)
    return portfolio, buyHold, trades, myTradeMetric

portfolio, buyHold, trades, myTradeMetric = oneRun(signalthreshold=100)
# build a metric which favors high median trades, but also rewards if there are many trades more
print("Final portfolio value:", portfolio[-1])
print("Final buy and hold value:", buyHold[-1])
print("median trade win:", np.median(trades))
print("myTradeMetric:", myTradeMetric)
print("win over buyhold:", portfolio[-1] - buyHold[-1])
# Out:
# Final portfolio value: 10212.889550117408
# Final buy and hold value: 10176.231434846537
# median trade win: -0.0006951093673706055
# myTradeMetric: -8.341312408447266e-05
# win over buyhold: 36.65811527087135

# %%
from random import randint
from tqdm import tqdm
bestWinOverBuyHold = -1000000
bestTradeMetric = -1000000
bestSettings = dict()

allSims = []

for signalthreshold in tqdm([1,5,8,10, 50, 100, 200, 500] + [randint(1, 1000) for _ in range(100)]):
    portfolio, buyHold, trades, myTradeMetric = oneRun(signalthreshold=signalthreshold)

    allSims.append({
        "signalthreshold": signalthreshold,
        "finalPortfolio": portfolio[-1],
        "finalBuyHold": buyHold[-1],
        "medianTrade": np.median(trades) if trades else 0,
        "myTradeMetric": myTradeMetric,
        "winOverBuyHold": portfolio[-1] - buyHold[-1],
        "nrTrades": len(trades),
    })

    winOverBuyHold = portfolio[-1] - buyHold[-1]
    if myTradeMetric > bestTradeMetric:
        bestTradeMetric = myTradeMetric
        bestSettings = allSims[-1]
print("Best win over buy and hold:", bestTradeMetric)
print("Best settings:", bestSettings) # 575

allSims = pd.DataFrame(allSims)
# Out:
#  13%|█▎        | 14/108 [00:04<00:30,  3.12it/s]/Users/jguese/code/myfxbookcopying/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/jguese/code/myfxbookcopying/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 108/108 [00:34<00:00,  3.13it/s]
# Best win over buy and hold: 0.00040596723556518555
# Best settings: {'signalthreshold': 5, 'finalPortfolio': np.float64(10213.314331684252), 'finalBuyHold': np.float64(10176.231434846537), 'medianTrade': np.float64(0.0016238689422607422), 'myTradeMetric': np.float64(0.00040596723556518555), 'winOverBuyHold': np.float64(37.08289683771545), 'nrTrades': 25}

# %% [markdown]
# best finalPortfolio: 449, 3 trades
# best medianTrade with at least 5 trades: 267, 5 trades, winOverBuyHold 51
# best myTradeMetric: 5, win over buyhold 71, 25 trades, 10247 usd
# best signalthres 1 performs good as well, 71 winoverbuyhold, 25 trades

# %%
filtered = allSims[allSims['nrTrades'] >= 5]
filtered = filtered.sort_values(by="winOverBuyHold", ascending=False)
filtered.head(10)
# Out:
#     signalthreshold  finalPortfolio  finalBuyHold  medianTrade  myTradeMetric  \
# 0                 1    10247.939666  10176.231435     0.001517       0.000379
# 59              267    10227.258493  10176.231435     0.005081       0.000254
# 1                 5    10213.314332  10176.231435     0.001624       0.000406
# 5               100    10212.889550  10176.231435    -0.000695      -0.000083
# 37              265    10205.793263  10176.231435     0.005079       0.000254
# 48              241    10191.812412  10176.231435     0.002865       0.000143
# 17              247    10190.357998  10176.231435     0.004036       0.000202
# 64              239    10178.965782  10176.231435     0.001692       0.000085
# 8                77    10178.528025  10176.231435     0.000275       0.000041
# 2                 8    10165.362664  10176.231435     0.001028       0.000247
#
#     winOverBuyHold  nrTrades
# 0        71.708231        25
# 59       51.027058         5
# 1        37.082897        25
# 5        36.658115        12
# 37       29.561828         5
# 48       15.580977         5
# 17       14.126563         5
# 64        2.734347         5
# 8         2.296590        15
# 2       -10.868771        24

# %%
# plot signalthreshold x, finalPortfolio y
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 7))
plt.plot(allSims['signalthreshold'], allSims['finalPortfolio'], marker='x', color='b')
plt.title('Final Portfolio Value vs Signal Threshold')
# Out:
# Text(0.5, 1.0, 'Final Portfolio Value vs Signal Threshold')

# %%
portfolio, buyHold, trades, myTradeMetric = oneRun(signalthreshold=267)
plt.figure(figsize=(14, 7))
plt.plot(portfolio, label='Portfolio Value', color='blue')
plt.plot(buyHold, label='Buy and Hold Value', color='orange')
plt.legend()
plt.title('Portfolio Value vs Buy and Hold Value')
# Out:
# Text(0.5, 1.0, 'Portfolio Value vs Buy and Hold Value')

# %%
# plot
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(portfolio, label="Strategy Portfolio")
plt.plot(buyHold, label="Buy and Hold Portfolio")
plt.title("Portfolio Performance")
plt.xlabel("Time")
plt.ylabel("Portfolio Value")
plt.legend()
plt.show()

# %%
## compare it to adapted_signal
portfolio, buyHold = oneRun(signalthreshold=575, signalcolumnname="adapted_signal")
print("Final portfolio value with adapted_signal:", portfolio[-1])
print("Final buy and hold value with adapted_signal:", buyHold[-1])
print("win over buyhold with adapted_signal:", portfolio[-1] - buyHold[-1])
# Out:
# Final portfolio value with adapted_signal: 10412.808085366349
# Final buy and hold value with adapted_signal: 10172.753057106253
# win over buyhold with adapted_signal: 240.05502826009615

# %% [markdown]
# # correlations

# %%
# Correlation of 'signal' with all other columns
data = data.drop(["adapted_signal"], axis=1)

data.corr()["signal"].sort_values(ascending=False)
# Out:
# Price
# signal                  1.000000
# trend_kst               0.056426
# trend_kst_sig           0.052568
# trend_vortex_ind_pos    0.043023
# trend_aroon_ind         0.041224
#                           ...
# volume_mfi                   NaN
# volume_nvi                   NaN
# momentum_pvo                 NaN
# momentum_pvo_signal          NaN
# momentum_pvo_hist            NaN
# Name: signal, Length: 92, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Example: Use all columns except 'signal' as features, and 'signal' as target
# Map signal values to 0, 1, 2 for classifier compatibility
y_mapped = data['signal'].map({-1: 0, 1: 1})
X = data.drop(columns=['signal'])
y = y_mapped

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
# Remove inf and -inf values from X_train and X_test
X_train = X_train.replace([np.inf, -np.inf], np.nan)
X_test = X_test.replace([np.inf, -np.inf], np.nan)

# Fill remaining NaNs with 0 (or use another strategy if preferred)
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# %%
# decision tree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1130
#            1       0.95      0.95      0.95      1286
#
#     accuracy                           0.94      2416
#    macro avg       0.94      0.94      0.94      2416
# weighted avg       0.94      0.94      0.94      2416
#
# Accuracy: 0.9441225165562914

# %%
# Print top 10 feature importances
importances = clf.feature_importances_
feature_names = X_train.columns
top_indices = np.argsort(importances)[::-1][:10]
for i in top_indices:
    print(f"{feature_names[i]}: {importances[i]:.4f}")
# Out:
# trend_visual_ichimoku_b: 0.2300
# trend_psar_up: 0.0807
# volatility_dch: 0.0527
# trend_ichimoku_b: 0.0480
# trend_visual_ichimoku_a: 0.0436
# volatility_dcl: 0.0361
# trend_adx: 0.0352
# volatility_atr: 0.0351
# trend_psar_down: 0.0342
# trend_ichimoku_base: 0.0259

# %% [markdown]
# ## reduce tree size

# %%
for maxdepth in range(1, 11):
    for maxfeatures in range(1, 11):
        clf = DecisionTreeClassifier(max_depth=maxdepth, max_features=maxfeatures)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        print(f"Max Depth: {maxdepth}, Max Features: {maxfeatures}")
        # print(classification_report(y_test, y_pred))
        print("Accuracy:", accuracy_score(y_test, y_pred))
        print("-" * 50)

# Preferred parameters: {'param_max_depth': 18, 'param_max_features': 19}
# Preferred accuracy: 0.9155456910299452
# Out:
# Max Depth: 1, Max Features: 1
# Accuracy: 0.5322847682119205
# --------------------------------------------------
# Max Depth: 1, Max Features: 2
# Accuracy: 0.5322847682119205
# --------------------------------------------------
# Max Depth: 1, Max Features: 3
# Accuracy: 0.5322847682119205
# --------------------------------------------------
# Max Depth: 1, Max Features: 4
# Accuracy: 0.6452814569536424
# --------------------------------------------------
# Max Depth: 1, Max Features: 5
# Accuracy: 0.6403145695364238
# --------------------------------------------------
# Max Depth: 1, Max Features: 6
# Accuracy: 0.6440397350993378
# --------------------------------------------------
# Max Depth: 1, Max Features: 7
# Accuracy: 0.6485927152317881
# --------------------------------------------------
# Max Depth: 1, Max Features: 8
# Accuracy: 0.6552152317880795
# --------------------------------------------------
# Max Depth: 1, Max Features: 9
# Accuracy: 0.6436258278145696
# --------------------------------------------------
# Max Depth: 1, Max Features: 10
# Accuracy: 0.6490066225165563
# --------------------------------------------------
# Max Depth: 2, Max Features: 1
# Accuracy: 0.6394867549668874
# --------------------------------------------------
# Max Depth: 2, Max Features: 2
# Accuracy: 0.6419701986754967
# --------------------------------------------------
# Max Depth: 2, Max Features: 3
# Accuracy: 0.6411423841059603
# --------------------------------------------------
# Max Depth: 2, Max Features: 4
# Accuracy: 0.6514900662251656
# --------------------------------------------------
# Max Depth: 2, Max Features: 5
# Accuracy: 0.6481788079470199
# --------------------------------------------------
# Max Depth: 2, Max Features: 6
# Accuracy: 0.6427980132450332
# --------------------------------------------------
# Max Depth: 2, Max Features: 7
# Accuracy: 0.6593543046357616
# --------------------------------------------------
# Max Depth: 2, Max Features: 8
# Accuracy: 0.6506622516556292
# --------------------------------------------------
# Max Depth: 2, Max Features: 9
# Accuracy: 0.6630794701986755
# --------------------------------------------------
# Max Depth: 2, Max Features: 10
# Accuracy: 0.6436258278145696
# --------------------------------------------------
# Max Depth: 3, Max Features: 1
# Accuracy: 0.5753311258278145
# --------------------------------------------------
# Max Depth: 3, Max Features: 2
# Accuracy: 0.6427980132450332
# --------------------------------------------------
# Max Depth: 3, Max Features: 3
# Accuracy: 0.6506622516556292
# --------------------------------------------------
# Max Depth: 3, Max Features: 4
# Accuracy: 0.5927152317880795
# --------------------------------------------------
# Max Depth: 3, Max Features: 5
# Accuracy: 0.6436258278145696
# --------------------------------------------------
# Max Depth: 3, Max Features: 6
# Accuracy: 0.6576986754966887
# --------------------------------------------------
# Max Depth: 3, Max Features: 7
# Accuracy: 0.6759105960264901
# --------------------------------------------------
# Max Depth: 3, Max Features: 8
# Accuracy: 0.6568708609271523
# --------------------------------------------------
# Max Depth: 3, Max Features: 9
# Accuracy: 0.6543874172185431
# --------------------------------------------------
# Max Depth: 3, Max Features: 10
# Accuracy: 0.6622516556291391
# --------------------------------------------------
# Max Depth: 4, Max Features: 1
# Accuracy: 0.6481788079470199
# --------------------------------------------------
# Max Depth: 4, Max Features: 2
# Accuracy: 0.6581125827814569
# --------------------------------------------------
# Max Depth: 4, Max Features: 3
# Accuracy: 0.6432119205298014
# --------------------------------------------------
# Max Depth: 4, Max Features: 4
# Accuracy: 0.6506622516556292
# --------------------------------------------------
# Max Depth: 4, Max Features: 5
# Accuracy: 0.6672185430463576
# --------------------------------------------------
# Max Depth: 4, Max Features: 6
# Accuracy: 0.6750827814569537
# --------------------------------------------------
# Max Depth: 4, Max Features: 7
# Accuracy: 0.6812913907284768
# --------------------------------------------------
# Max Depth: 4, Max Features: 8
# Accuracy: 0.6949503311258278
# --------------------------------------------------
# Max Depth: 4, Max Features: 9
# Accuracy: 0.6771523178807947
# --------------------------------------------------
# Max Depth: 4, Max Features: 10
# Accuracy: 0.6746688741721855
# --------------------------------------------------
# Max Depth: 5, Max Features: 1
# Accuracy: 0.6552152317880795
# --------------------------------------------------
# Max Depth: 5, Max Features: 2
# Accuracy: 0.660182119205298
# --------------------------------------------------
# Max Depth: 5, Max Features: 3
# Accuracy: 0.6775662251655629
# --------------------------------------------------
# Max Depth: 5, Max Features: 4
# Accuracy: 0.6655629139072847
# --------------------------------------------------
# Max Depth: 5, Max Features: 5
# Accuracy: 0.6825331125827815
# --------------------------------------------------
# Max Depth: 5, Max Features: 6
# Accuracy: 0.6995033112582781
# --------------------------------------------------
# Max Depth: 5, Max Features: 7
# Accuracy: 0.6978476821192053
# --------------------------------------------------
# Max Depth: 5, Max Features: 8
# Accuracy: 0.6961920529801324
# --------------------------------------------------
# Max Depth: 5, Max Features: 9
# Accuracy: 0.7065397350993378
# --------------------------------------------------
# Max Depth: 5, Max Features: 10
# Accuracy: 0.7160596026490066
# --------------------------------------------------
# Max Depth: 6, Max Features: 1
# Accuracy: 0.6825331125827815
# --------------------------------------------------
# Max Depth: 6, Max Features: 2
# Accuracy: 0.6655629139072847
# --------------------------------------------------
# Max Depth: 6, Max Features: 3
# Accuracy: 0.6738410596026491
# --------------------------------------------------
# Max Depth: 6, Max Features: 4
# Accuracy: 0.703228476821192
# --------------------------------------------------
# Max Depth: 6, Max Features: 5
# Accuracy: 0.7090231788079471
# --------------------------------------------------
# Max Depth: 6, Max Features: 6
# Accuracy: 0.6920529801324503
# --------------------------------------------------
# Max Depth: 6, Max Features: 7
# Accuracy: 0.7123344370860927
# --------------------------------------------------
# Max Depth: 6, Max Features: 8
# Accuracy: 0.6879139072847682
# --------------------------------------------------
# Max Depth: 6, Max Features: 9
# Accuracy: 0.6982615894039735
# --------------------------------------------------
# Max Depth: 6, Max Features: 10
# Accuracy: 0.6995033112582781
# --------------------------------------------------
# Max Depth: 7, Max Features: 1
# Accuracy: 0.6494205298013245
# --------------------------------------------------
# Max Depth: 7, Max Features: 2
# Accuracy: 0.6875
# --------------------------------------------------
# Max Depth: 7, Max Features: 3
# Accuracy: 0.695364238410596
# --------------------------------------------------
# Max Depth: 7, Max Features: 4
# Accuracy: 0.6875
# --------------------------------------------------
# Max Depth: 7, Max Features: 5
# Accuracy: 0.7110927152317881
# --------------------------------------------------
# Max Depth: 7, Max Features: 6
# Accuracy: 0.7102649006622517
# --------------------------------------------------
# Max Depth: 7, Max Features: 7
# Accuracy: 0.7475165562913907
# --------------------------------------------------
# Max Depth: 7, Max Features: 8
# Accuracy: 0.7330298013245033
# --------------------------------------------------
# Max Depth: 7, Max Features: 9
# Accuracy: 0.7276490066225165
# --------------------------------------------------
# Max Depth: 7, Max Features: 10
# Accuracy: 0.734271523178808
# --------------------------------------------------
# Max Depth: 8, Max Features: 1
# Accuracy: 0.6846026490066225
# --------------------------------------------------
# Max Depth: 8, Max Features: 2
# Accuracy: 0.6721854304635762
# --------------------------------------------------
# Max Depth: 8, Max Features: 3
# Accuracy: 0.6957781456953642
# --------------------------------------------------
# Max Depth: 8, Max Features: 4
# Accuracy: 0.7185430463576159
# --------------------------------------------------
# Max Depth: 8, Max Features: 5
# Accuracy: 0.7119205298013245
# --------------------------------------------------
# Max Depth: 8, Max Features: 6
# Accuracy: 0.7160596026490066
# --------------------------------------------------
# Max Depth: 8, Max Features: 7
# Accuracy: 0.7466887417218543
# --------------------------------------------------
# Max Depth: 8, Max Features: 8
# Accuracy: 0.8108443708609272
# --------------------------------------------------
# Max Depth: 8, Max Features: 9
# Accuracy: 0.7520695364238411
# --------------------------------------------------
# Max Depth: 8, Max Features: 10
# Accuracy: 0.7359271523178808
# --------------------------------------------------
# Max Depth: 9, Max Features: 1
# Accuracy: 0.6841887417218543
# --------------------------------------------------
# Max Depth: 9, Max Features: 2
# Accuracy: 0.7102649006622517
# --------------------------------------------------
# Max Depth: 9, Max Features: 3
# Accuracy: 0.7222682119205298
# --------------------------------------------------
# Max Depth: 9, Max Features: 4
# Accuracy: 0.7255794701986755
# --------------------------------------------------
# Max Depth: 9, Max Features: 5
# Accuracy: 0.7450331125827815
# --------------------------------------------------
# Max Depth: 9, Max Features: 6
# Accuracy: 0.7748344370860927
# --------------------------------------------------
# Max Depth: 9, Max Features: 7
# Accuracy: 0.7740066225165563
# --------------------------------------------------
# Max Depth: 9, Max Features: 8
# Accuracy: 0.7644867549668874
# --------------------------------------------------
# Max Depth: 9, Max Features: 9
# Accuracy: 0.7926324503311258
# --------------------------------------------------
# Max Depth: 9, Max Features: 10
# Accuracy: 0.7913907284768212
# --------------------------------------------------
# Max Depth: 10, Max Features: 1
# Accuracy: 0.6986754966887417
# --------------------------------------------------
# Max Depth: 10, Max Features: 2
# Accuracy: 0.7098509933774835
# --------------------------------------------------
# Max Depth: 10, Max Features: 3
# Accuracy: 0.7197847682119205
# --------------------------------------------------
# Max Depth: 10, Max Features: 4
# Accuracy: 0.7595198675496688
# --------------------------------------------------
# Max Depth: 10, Max Features: 5
# Accuracy: 0.7760761589403974
# --------------------------------------------------
# Max Depth: 10, Max Features: 6
# Accuracy: 0.7984271523178808
# --------------------------------------------------
# Max Depth: 10, Max Features: 7
# Accuracy: 0.7884933774834437
# --------------------------------------------------
# Max Depth: 10, Max Features: 8
# Accuracy: 0.8004966887417219
# --------------------------------------------------
# Max Depth: 10, Max Features: 9
# Accuracy: 0.7876655629139073
# --------------------------------------------------
# Max Depth: 10, Max Features: 10
# Accuracy: 0.820364238410596
# --------------------------------------------------

# %% [markdown]
# ## finetune the signal smoothing
